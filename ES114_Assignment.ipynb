# %%
# Question 1

list_of_numbers =[]
for i in range (1 , 21):
    list_of_numbers.append(i)
print(list_of_numbers)
total = 0
for i in range (9,len(list_of_numbers)) :
    if list_of_numbers[i] % 2 == 0 :
        n = list_of_numbers[i]
        n=list_of_numbers[i]
        total += n
print(total)

import statistics as st
 
mean = st.mean(list_of_numbers)
print("Mean :", mean)
median = st.median(list_of_numbers)
print("median :", median)
standered_deviation = st.stdev(list_of_numbers)
print("standered_deviantion :",standered_deviation)

# %%
#Question 2

# mutable datatype   : matable object can be modified after creation without changing their identity . Eg : list , dict , set 
# immutable datatype : immutabele object cannot  be modified after creation ,if modified a new identity should
#  be formed . Eg : int , float , str, tupple

# %%
#Question 3

n = int(input())
number = []
for i in range(1,n) :
    number.append(i)
print (number)
list_fibonacci = []
a = 0
b = 1
i = 1 
while i < n :
    m = a + b
    a = b
    b = m
    i += 1
    list_fibonacci.append(m)
print(list_fibonacci)


from matplotlib import pyplot as plt 

x = number 
y = list_fibonacci

plt.plot(x,y)
plt.show()

# %%
#Question 4

list =[ 3 , 5 , 7 , 9 , 11 , 13 ]
list.insert(3,6)
print(list)
list.remove(7)
print(list)
list.reverse()
print(list)

import statistics as st

mean = st.mean(list)
print(mean)
median = st.median(list)
print(median)

# %%
#question 5

number = input()

num = number.split(',')
list_of_number = []
for i in num:
    numb = int(i.strip())
    list_of_number.append(numb)

print(list_of_number)

import statistics as st

mean = st.mean(list_of_number)
print(mean)
print(max(list_of_number))
print(min(list_of_number))

from matplotlib import pyplot as pt

x = num 
y = list_of_number  

pt.hist(y )
pt.show()

# %%
#Question 6

a=input()
m=[]
n=[]
for i in a :
    if i ==" ":
        continue
    else:
        m.append(i.lower())
for i in range (len(m)):
    n.append(m[len(m)-i-1])
if n==m:
    print("True")
else:
    print("False")

# %%
#Question 7



student_marks = {
    "a" : 45,
    "b" : 36, 
    "c" : 66,
    "d" : 54
}

alpha = []
for value in student_marks.values():
    alpha.append(int(value))

i=0
sum=0
while i <= (len(alpha)-1) :
    sum = sum + alpha[i]
    i+=1
average = sum/(len(alpha))
print(average)

for i in alpha :
    if i>average :
        print(i)

beta =[]
for value in student_marks:
    beta.append(value)

print(beta)

from matplotlib import pyplot as pt 

x=beta
y= alpha
pt.bar(x,y)
pt.show

# %%
#Question 8
n=int(input())

b=[]
number = []
square = []

i=1
while  i <= n :
    c = i
    d = i**2
    e = (c,d)
    b.append(e)
    number.append(i)
    square.append(i**2)

    i+=1

print(b)

from matplotlib import pyplot as plt

x= number 
y= square 
 
plt.scatter(x,y)
plt.show()

# %%
#Question 9

dict1 = {'a': 10, 'b': 20}
dict2 = {'b': 5, 'c': 15}
ans=dict1
for key in dict2:
    if key in ans:
        ans[key]=ans[key]+dict2[key]
    else:
        ans[key]=dict2[key] 
print(ans)

# %%
#Question 10



from matplotlib import pyplot as pyt

def my():
    n= input()
    n.lower()
    print(n)
    from collections import Counter
    text = "hello world"
    frequency = Counter(text)
    print(frequency)  
    a= list(frequency.keys())
    b= list(frequency.values())

  

    x=a
    y=b
    pyt.bar(x,y)
    pyt.show()


my()

# %%
#Question 11


n = int( input() )

b=[]
for i in range (n):
    b.append(i**2)
    b.append(i**4)
k=[]
for i in b:
    if i not in k:
        k.append(i)
print(b)
print(k)

# %%
#Question 12

random_strings = [
    "apple",
    "quantum mechanics",
    "sunset at the beach",
    "42",
    "elephants in the Sahara desert",
    "A",
    "To be or not to be, that is the question.",
    "AI-powered chat assistants",
    "hello",
    "supercalifragilisticexpialidocious",
    "1234567890",
    "blue sky",
    "a stitch in time saves nine",
    "XYZ",
    "the quick brown fox jumps over the lazy dog",
    "😊🌟",
    "data-driven decision-making processes",
    "chatGPT",
    "0",
    "innovation and creativity"
]
b=[]
for i in random_strings :
    b.append(len(i))
print(b)
c=max(b)
for i in random_strings:
    if len(i)==c:
        print(i)
d = []
for i in random_strings:
     if i[0].lower() in ['a', 'e', 'i', 'o', 'u']:
        d.append(i)
print(len(d))
print(d)

from matplotlib import pyplot as plt 

plt.hist(b)
plt.show()

# %%
#  Question 13
list_of_dicts = [
    {'name': 'Alice', 'age': 25},
    {'name': 'Bob', 'age': 30},
    {'name': 'Charlie', 'age': 20}
]


sorted_list = sorted(list_of_dicts, key=lambda d: d['age'])
print(sorted_list)

# %%
#  Question 14
a = "To be or not to be that is the question"
b = a.split()
print(b)


filtered_words = [i for i in b if len(i) >= 4]

print(filtered_words)

filtered_words.sort()
print(filtered_words)
d=[]
for i in b :
   d.append(len(i)) 
print(d)
from matplotlib import pyplot as plt 
plt.bar(b,d)
plt.show()
